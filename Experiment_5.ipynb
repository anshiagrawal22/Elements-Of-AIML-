# %% [markdown]
# <a href="https://colab.research.google.com/github/anshiagrawal22/Elements-Of-AIML-/blob/main/Experiment_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/DATASET_COS.csv')

# %%
df.head(8)
# Out:
#          Label           Brand                                           Name  \
# 0  Moisturizer          LA MER                                Crème de la Mer
# 1  Moisturizer           SK-II                       Facial Treatment Essence
# 2  Moisturizer  DRUNK ELEPHANT                     Protini™ Polypeptide Cream
# 3  Moisturizer          LA MER                    The Moisturizing Soft Cream
# 4  Moisturizer    IT COSMETICS  Your Skin But Better™ CC+™ Cream with SPF 50+
# 5  Moisturizer          TATCHA                                The Water Cream
# 6  Moisturizer  DRUNK ELEPHANT                      Lala Retro™ Whipped Cream
# 7  Moisturizer  DRUNK ELEPHANT                Virgin Marula Luxury Facial Oil
#
#    Price  Rank                                        Ingredients  \
# 0    175   4.1  Algae (Seaweed) Extract, Mineral Oil, Petrolat...
# 1    179   4.1  Galactomyces Ferment Filtrate (Pitera), Butyle...
# 2     68   4.4  Water, Dicaprylyl Carbonate, Glycerin, Ceteary...
# ...

# %%
df.tail(8)
# Out:
#             Label                          Brand  \
# 1464  Sun protect                   IT COSMETICS
# 1465  Sun protect                    URBAN DECAY
# 1466  Sun protect                KATE SOMERVILLE
# 1467  Sun protect                         KORRES
# 1468  Sun protect                KATE SOMERVILLE
# 1469  Sun protect                  VITA LIBERATA
# 1470  Sun protect  ST. TROPEZ TANNING ESSENTIALS
# 1471  Sun protect                     DERMAFLASH
#
#                                                    Name  Price  Rank  \
# 1464  Anti-Aging Armour™ Super Smart Skin-Perfecting...     38   4.1
# 1465  Naked Skin Bronzing Beauty Balm Broad Spectrum...     34   4.1
# 1466  Daily Deflector™ Moisturizer Broad Spectrum SP...     48   3.9
# 1467  Yoghurt Nourishing Fluid Veil Face Sunscreen B...     35   3.9
# 1468  Daily Deflector™ Waterlight Broad Spectrum SPF...     48   3.6
# 1469                            Self Tan Dry Oil SPF 50     54   3.5
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1472 entries, 0 to 1471
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Label        1472 non-null   object
#  1   Brand        1472 non-null   object
#  2   Name         1472 non-null   object
#  3   Price        1472 non-null   int64
#  4   Rank         1472 non-null   float64
#  5   Ingredients  1472 non-null   object
#  6   Combination  1461 non-null   float64
#  7   Dry          1450 non-null   float64
#  8   Normal       1461 non-null   float64
#  9   Oily         1472 non-null   int64
#  10  Sensitive    1461 non-null   float64
# dtypes: float64(5), int64(2), object(4)
# memory usage: 126.6+ KB

# %%
df.shape
# Out:
# (1472, 11)

# %%
df.describe()
# Out:
#              Price         Rank  Combination          Dry       Normal  \
# count  1472.000000  1472.000000  1461.000000  1450.000000  1461.000000
# mean     55.584239     4.153261     0.656400     0.616552     0.653662
# std      45.014429     0.633918     0.475072     0.486394     0.475965
# min       3.000000     0.000000     0.000000     0.000000     0.000000
# 25%      30.000000     4.000000     0.000000     0.000000     0.000000
# 50%      42.500000     4.300000     1.000000     1.000000     1.000000
# 75%      68.000000     4.500000     1.000000     1.000000     1.000000
# max     370.000000     5.000000     1.000000     1.000000     1.000000
#
#               Oily    Sensitive
# count  1472.000000  1461.000000
# mean      0.607337     0.513347
# std       0.488509     0.499993
# min       0.000000     0.000000
# 25%       0.000000     0.000000
# 50%       1.000000     1.000000
# 75%       1.000000     1.000000
# max       1.000000     1.000000

# %%
print("\nMinimum Values in Numerical Columns:")
print(numerical_cols.min())
# Out:
# Minimum Values in Numerical Columns:
# Price          3.0
# Rank           0.0
# Combination    0.0
# Dry            0.0
# Normal         0.0
# Oily           0.0
# Sensitive      0.0
# dtype: float64

# %%
df.select_dtypes(include='number').hist(figsize=(12, 10), bins=20, color='hotpink')
plt.suptitle('Histograms of Numerical Features', size=16)
plt.show()

# %%
for col in df.select_dtypes(include='number').columns:
    plt.figure(figsize=(8, 4))
    sns.boxplot(x=df[col])
    plt.title(f'Boxplot for {col}')
    plt.show()
